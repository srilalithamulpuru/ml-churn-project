# %%
# Separate features & target
import pandas as pd
df = pd.read_csv("/content/encoded_data.csv")

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']
df['Churn'].value_counts()
# Out:
# Churn
# -0.601023    5174
#  1.663829    1869
# Name: count, dtype: int64

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0}).astype(int)
df['Churn'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipython-input-732750006.py in <cell line: 0>()
# ----> 1 df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0}).astype(int)
#       2 df['Churn'].value_counts()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
X_train.select_dtypes(include='object').columns
# Out:
# Index(['PhoneService'], dtype='object')

# %%
#Train Logistic Regression

from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    max_iter=1000,
    class_weight="balanced"
)

model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2730223951.py in <cell line: 0>()
#       8 )
#       9
# ---> 10 model.fit(X_train, y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1220             _dtype = [np.float64, np.float32]
#    1221
# -> 1222         X, y = validate_data(
#    1223             self,
#    1224             X,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
# ...

# %%
# finding the column which contains "No"

df.select_dtypes(include='object').columns

for col in df.select_dtypes(include='object').columns:
    print(col, df[col].unique())
# Out:
# PhoneService ['No' 'Yes']

# %%
df['PhoneService'] = df['PhoneService'].map({'Yes': 1, 'No': 0})
print(df.select_dtypes(include='object').columns)
df['PhoneService'].unique()
# Out:
# Index([], dtype='object')
# array([0, 1])

# %% [markdown]
# In notebooks, stale feature matrices can cause encoding errors. Rebuilding the pipeline after preprocessing changes is essential

# %%
'''from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\n\nscaler = StandardScaler()\n\nX_train_scaled = scaler.fit_transform(X_train)\nX_test_scaled = scaler.transform(X_test)'

# %%
#Train Logistic Regression

from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    max_iter=1000,
    class_weight='balanced'
)

model.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1269996303.py in <cell line: 0>()
#       8 )
#       9
# ---> 10 model.fit(X_train_scaled, y_train)
#      11
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1229             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1230         )
# -> 1231         check_classification_targets(y)
#    1232         self.classes_ = np.unique(y)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
# ...

# %%
df["Churn"].unique()
# Out:
# array([-0.60102348,  1.66382851])

# %% [markdown]
# ##### the dataset is a continous one since it has continous data not just 0/1

# %% [markdown]
# Since it is a continous data using Logistic regression

# %%
'''df['Churn'] = df['Churn'].apply(lambda x: 1 if x in ['Yes', 1] else 0)
df['Churn'] = df['Churn'].astype(int)'''

'''df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})
df['Churn'] = df['Churn'].astype(int)'''

df['Churn'].value_counts()
# Out:
# Churn
# -0.601023    5174
#  1.663829    1869
# Name: count, dtype: int64

# %%
df['Churn'].unique(), df['Churn'].dtype
# o/p should have 2 values 0&1
# Out:
# (array([-0.60102348,  1.66382851]), dtype('float64'))

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})
df['Churn'] = df['Churn'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipython-input-2928346529.py in <cell line: 0>()
#       1 df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})
# ----> 2 df['Churn'] = df['Churn'].astype(int)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
# ...

# %%
df.isnull().sum()
# Out:
# gender                            0
# SeniorCitizen                     0
# tenure                            0
# PhoneService                      0
# MultipleLines                     0
# OnlineSecurity                    0
# OnlineBackup                      0
# DeviceProtection                  0
# TechSupport                       0
# MonthlyCharges                    0
# TotalCharges                      0
# Churn                          7043
# InternetService_Fiber optic       0
# InternetService_No                0
# Contract_One year                 0
# Contract_Two year                 0
# AvgCharges                        0
# dtype: int64

# %% [markdown]
# #### IMP NOTE: Once a target column is scaled, it is permanently corrupted for classification.
# #### You must reload raw data and execute all previous cows from scarch
